# %%
def transcribe_gcs(gcs_uri):
    from google.cloud import speech
    from google.cloud.speech import enums
    from google.cloud.speech import types
    client = speech.SpeechClient()
    audio = types.RecognitionAudio(uri=gcs_uri)
    config = types.RecognitionConfig(
        encoding=enums.RecognitionConfig.AudioEncoding.LINEAR16,
        sample_rate_hertz=16000,
        language_code='ko-KR',
        enable_word_time_offsets=True)
    operation = client.long_running_recognize(config, audio)
    response = operation.result(timeout=60)
    return response
response = transcribe_gcs("gs://thirdproj/data/test1.wav")
with open("result/test1.txt", "w") as script:
    for result in response.results:
        script.write(u'{}'.format(result.alternatives[0].transcript)+"\n")

# %%
def transcribe_gcs_with_word_time_offsets(gcs_uri):
    ans = []
    """Transcribe the given audio file asynchronously and output the word time
    offsets."""
    from google.cloud import speech
    from google.cloud.speech import enums
    from google.cloud.speech import types
    client = speech.SpeechClient()

    audio = types.RecognitionAudio(uri=gcs_uri)
    config = types.RecognitionConfig(
        encoding=enums.RecognitionConfig.AudioEncoding.LINEAR16,
        sample_rate_hertz=16000,
        language_code='ko-KR',
        enable_word_time_offsets=True)

    operation = client.long_running_recognize(config, audio)

    #print('Waiting for operation to complete...')
    result = operation.result(timeout=90)

    for result in result.results:
        alternative = result.alternatives[0]
        #print(u'Transcript: {}'.format(alternative.transcript))
        #print('Confidence: {}'.format(alternative.confidence))

        for word_info in alternative.words:
            word = word_info.word
            start_time = word_info.start_time
            end_time = word_info.end_time
            #ans.append([word,start_time.seconds,end_time.seconds])
            ans.append([word,start_time.seconds + start_time.nanos * 1e-9,end_time.seconds + end_time.nanos * 1e-9])
    print('STT complished')
    return ans
#test1 = transcribe_gcs_with_word_time_offsets("gs://thirdproj/data/test1.wav")
# Out:
# Waiting for operation to complete...
# Transcript: 안녕하세요 경미한 예리 인사담당자 영상입니다 경영학을 전공하고 여러기업 교육 프로그램을 개발 하면서 이론의 폭을 넓혔습니다 N4 인사팀에서의 새로운 보조와 HID 컨설팅회사의 교육 및 평가 운영을 하면서 실물하고 물론 인사해 서호 통영까지 김다미 얼마나 중요한지 깨닫게 되었습니다 저는 교외학습 모임인 브레이브 his 설립했을 때 팀원들과 함께 소통하며 그에 맞는 hrd 학술지를 3년간 발행한 경험이 있으며 인사동아리랑 최대의 아카데미에서는 조직운영에 어려워서 톡 확인을 복합 대신 TF를 자발적으로 결성해 일을 해결했던 경험에 있습니다 직무와 속상해 적합도와 전공 및 실무 경험을 토대로 향상에 기여하는 인사담당자가 되겠습니다 감사합니다
# Confidence: 0.9057092666625977
# Word: 안녕하세요, start_time: 0.0, end_time: 1.0
# Word: 경미한, start_time: 1.0, end_time: 2.8
# Word: 예리, start_time: 2.8, end_time: 3.1
# Word: 인사담당자, start_time: 3.1, end_time: 3.9
# Word: 영상입니다, start_time: 3.9, end_time: 4.6
# Word: 경영학을, start_time: 4.6, end_time: 6.8
# Word: 전공하고, start_time: 6.8, end_time: 7.2
# Word: 여러기업, start_time: 7.2, end_time: 8.3
# Word: 교육, start_time: 8.3, end_time: 8.6
# Word: 프로그램을, start_time: 8.6, end_time: 9.1
# Word: 개발, start_time: 9.1, end_time: 9.4
# Word: 하면서, start_time: 9.4, end_time: 9.8
# ...
